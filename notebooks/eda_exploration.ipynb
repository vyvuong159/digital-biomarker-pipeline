# %%
# Load the data generator
from src.data_gen import SyntheticDataGenerator

# %%
# Instantiate the data generate and generate synthetic datasets
generator = SyntheticDataGenerator(seed = 42)
data = generator.generate_synthetic_data(seed=42)
# Out:
# Initializing Data Pipeline Synthesis...

# %%
# Extract the individual datasets from the generated data
baseline_df = data['baseline_classifier_data']
burst_df = data['cam_cog_burst_data']
tele_df = data['tele_research_validation_data']
sensor_df = data['sensor_kit_data']
health_df = data['health_kit_data']

# %%
baseline_df.head()
# Out:
#   Participant_ID        Age  Sex_Female  Education_Low  CFI_Total  \
# 0      SUB_00362  66.197291           1              0   6.227713
# 1      SUB_03398  81.373003           1              0   2.218220
# 2      SUB_09229  65.834866           0              0   0.866236
# 3      SUB_10922  77.376960           1              0   2.508776
# 4      SUB_03802  57.300749           1              1   3.969975
#
#    ECog_12_Total  MCI_Status    CFI_Q1    CFI_Q2    CFI_Q3  ...  \
# 0       1.000000           1  0.427018  0.468206  0.451436  ...
# 1       1.286517           0  0.012862  0.160041  0.185770  ...
# 2       1.437219           0  0.000000  0.000000  0.188129  ...
# 3       1.219931           0  0.295824  0.483370  0.163083  ...
# 4       1.429027           0  0.159033  0.477347  0.206603  ...
#
#    CANTAB_Metric_167  CANTAB_Metric_168  CANTAB_Metric_169  CANTAB_Metric_170  \
# 0           1.182677          -1.951911           0.477257           1.006139
# ...
